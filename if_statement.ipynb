# %% [markdown]
# # Python If Statement

# %% [markdown]
# # If statement evaluates a condition (an expression that results in a True or False).
# # if the condition is True the code block inside the if statement will be excecuted and if False the code block will be skipped.

# %%
x = 20
if x < 30:
    print("x is less than 30")
# Out:
# x is less than 30

# %%
y = 7
if y > 8:
    print("y is greater than 8")
if y == 7:
    print("y is the same as 7")
# Out:
# y is the same as 7

# %% [markdown]
# # Write a python program that will take a number from the user and your program should that the number is odd or even.Hint use the % operator and the if statement

# %%
number = int(input("Enter a number: "))
if number %2 == 0:
    print("Even")
if number %2 != 0:
    print("Odd")
# Out:
# Enter a number: 77777
# Odd

# %%
20//5
# Out:
# 4

# %%
20%5
# Out:
# 0

# %% [markdown]
# # The Elif Keyword

# %% [markdown]
# # The Elif keyword is python's way of saying "if the previous conditions were not true, then try this condition"
# # The Elif keyword allows you to check multiple expressions for True and execute a block of code as soon as one of the conditions evaluates to True

# %%
a = 20
b = 5
if a < b:
    print("a is less")
elif a == b:
    print("a and b are equal")
elif b > a:
    print("b is greater than a")
elif b < a:
    print("b is less than a")
# Out:
# b is less than a

# %% [markdown]
# # Write a program that will ask the students to put in their exam scores  and the program should display the students grades. 70-100 = A, 60-69 = B, 50-59 = C, 40-49 = D and less than 40 should display F.

# %%
exam_score = int(input("Enter your score: "))
if exam_score >= 70:
    print("Your grade is A - Congratulations")
elif exam_score >= 60:
    print("Your grade is B")
elif exam_score >= 50:
    print("Your grade is C")
elif exam_score >= 40:
    print("Your grade is D")
elif exam_score < 40:
    print("Your grade is F and you failed")
# Out:
# Enter your score: 2
# Your grade is F and you failed

# %%
number = int(input("Enter a number: "))
if number % 2 ==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# Enter a number: 43
# the number is odd

# %% [markdown]
# # Else Statement
#
# # The else statement catches anything which isn't caught by the preceding conditions.
# # The else statement is executed when the if condition (and any of the elif conditions) evaluate to False.

# %%
x = 40
y = 30
if y > x:
    print("y is greater than x")
elif x == y:
    print("x and y are equal")
else:
    print("x is greater")
# Out:
# x is greater

# %%
exam_score = int(input("Enter your score: "))
if exam_score >= 70:
    print("Your grade is A - Congratulations")
elif exam_score >= 60:
    print("Your grade is B")
elif exam_score >= 50:
    print("Your grade is C")
elif exam_score >= 40:
    print("Your grade is D")
else:
    print("Your grade is F and you failed")
# Out:
# Enter your score: 34
# Your grade is F and you failed

# %%
a = "aeiou"
if "i" in a:
    print(a)
# Out:
# aeiou

# %%
for a in 'aeiou':
    print(a)
# Out:
# a
# e
# i
# o
# u

# %% [markdown]
# # Exercise 2:Hello
#
# ## Write a program that asks the user to enter his or her name. The program should respond with a message that says hello to the user, using his or her name

# %%
name = input("Enter your name: ")
print("Hello," " " + name)
# Out:
# Enter your name: Precious
# Hello, Precious

# %% [markdown]
# # Exercise 36:Vowel or Consonant
#
# ## In this exercise you will create a program that reads a letter of the alphabet from the user. If the user enters a, e, i, o or u then your program should display a message indicating that the entered letter is a vowel. If the user enters y then your program should display a message indicating that sometimes y is a vowel, and sometimes y is a consonant. Otherwise your program should display a message indicating that the letter is a consonant

# %%
letter = input("Enter a letter: ").lower()
if letter == 'a' or letter == 'e' or letter == 'i' or letter == 'o' or letter == 'u':
    print("vowel")
elif letter == 'y':
    print("sometimes y is a vowel, and sometimes y is a consonant")
else:
    print("consonant")
# Out:
# Enter a letter: y
# sometimes y is a vowel, and sometimes y is a consonant
